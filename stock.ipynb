# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
#read the file
df = pd.read_csv('NSE-TATAGLOBAL11.csv')
#print the head
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
#setting index as date
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#plot
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')
# Out:
# C:\Users\vikra\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
#creating dataframe with date and the target variable
data = df.sort_index(ascending=True, axis=0)
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])

for i in range(0,len(data)):
     new_data['Date'][i] = data['Date'][i]
     new_data['Close'][i] = data['Close'][i]

# %%
#splitting into train and validation
train = new_data[:987]
valid = new_data[987:]

# %%
new_data.shape, train.shape, valid.shape
# Out:
# ((1235, 2), (987, 2), (248, 2))

# %%
train['Date'].min(), train['Date'].max(), valid['Date'].min(), valid['Date'].max()
# Out:
# (Timestamp('2013-10-08 00:00:00'),
#  Timestamp('2017-10-06 00:00:00'),
#  Timestamp('2017-10-09 00:00:00'),
#  Timestamp('2018-10-08 00:00:00'))

# %%
#make predictions
preds = []
for i in range(0,248):
    a = train['Close'][len(train)-248+i:].sum() + sum(preds)
    b = a/248
    preds.append(b)

# %%
#calculate rmse
rms=np.sqrt(np.mean(np.power((np.array(valid['Close'])-preds),2)))
rms
# Out:
# 104.51415465984348

# %%
#plot
valid['Predictions'] = 0
valid['Predictions'] = preds
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])

# %%
pip install fastai
# Out:
# Requirement already satisfied: fastai in c:\users\vikra\anaconda3\lib\site-packages (1.0.55)
# Requirement already satisfied: numpy>=1.15 in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (1.16.2)
# Requirement already satisfied: torch>=1.0.0 in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (1.1.0)
# Requirement already satisfied: packaging in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (19.0)
# Requirement already satisfied: spacy>=2.0.18 in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (2.1.6)
# Requirement already satisfied: pandas in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (0.24.2)
# Requirement already satisfied: bottleneck in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (1.2.1)
# Requirement already satisfied: Pillow in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (5.4.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\vikra\appdata\roaming\python\python37\site-packages (from fastai) (4.7.1)
# Requirement already satisfied: scipy in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (1.2.1)
# Requirement already satisfied: nvidia-ml-py3 in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (7.352.0)
# Requirement already satisfied: numexpr in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (2.6.9)
# Requirement already satisfied: pyyaml in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (5.1)
# Requirement already satisfied: matplotlib in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (3.0.3)
# Requirement already satisfied: requests in c:\users\vikra\appdata\roaming\python\python37\site-packages (from fastai) (2.22.0)
# Requirement already satisfied: torchvision in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (0.3.0)
# Requirement already satisfied: fastprogress>=0.1.19 in c:\users\vikra\anaconda3\lib\site-packages (from fastai) (0.1.21)
# Requirement already satisfied: six in c:\users\vikra\anaconda3\lib\site-packages (from packaging->fastai) (1.12.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vikra\anaconda3\lib\site-packages (from packaging->fastai) (2.3.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (2.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (0.2.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (1.0.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (2.0.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (0.2.4)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (0.9.6)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (7.0.8)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in c:\users\vikra\anaconda3\lib\site-packages (from spacy>=2.0.18->fastai) (0.0.7)
# Requirement already satisfied: pytz>=2011k in c:\users\vikra\appdata\roaming\python\python37\site-packages (from pandas->fastai) (2019.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\vikra\anaconda3\lib\site-packages (from pandas->fastai) (2.8.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\vikra\appdata\roaming\python\python37\site-packages (from beautifulsoup4->fastai) (1.9.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vikra\anaconda3\lib\site-packages (from matplotlib->fastai) (1.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\vikra\appdata\roaming\python\python37\site-packages (from requests->fastai) (1.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\vikra\appdata\roaming\python\python37\site-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\vikra\appdata\roaming\python\python37\site-packages (from requests->fastai) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vikra\appdata\roaming\python\python37\site-packages (from requests->fastai) (2019.6.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\vikra\anaconda3\lib\site-packages (from thinc<7.1.0,>=7.0.8->spacy>=2.0.18->fastai) (4.31.1)
# Requirement already satisfied: setuptools in c:\users\vikra\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->fastai) (40.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#setting index as date values
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']

#sorting
data = df.sort_index(ascending=True, axis=0)

#creating a separate dataset
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])

for i in range(0,len(data)):
    new_data['Date'][i] = data['Date'][i]
    new_data['Close'][i] = data['Close'][i]

# %%
#create features
from fastai.tabular import  add_datepart
add_datepart(new_data, 'Date')
new_data.drop('Elapsed', axis=1, inplace=True)  #elapsed will be the time stamp

# %%
new_data['mon_fri'] = 0
for i in range(0,len(new_data)):
    if (new_data['Dayofweek'][i] == 0 or new_data['Dayofweek'][i] == 4):
        new_data['mon_fri'][i] = 1
    else:
        new_data['mon_fri'][i] = 0
# Out:
# C:\Users\vikra\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\vikra\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#split into train and validation
train = new_data[:987]
valid = new_data[987:]

x_train = train.drop('Close', axis=1)
y_train = train['Close']
x_valid = valid.drop('Close', axis=1)
y_valid = valid['Close']

#implement linear regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#make predictions and find the rmse
preds = model.predict(x_valid)
rms=np.sqrt(np.mean(np.power((np.array(y_valid)-np.array(preds)),2)))
rms
# Out:
# 121.16291596523389

# %%
#plot
valid['Predictions'] = 0
valid['Predictions'] = preds

valid.index = new_data[987:].index
train.index = new_data[:987].index

plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
# Out:
# C:\Users\vikra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\vikra\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [<matplotlib.lines.Line2D at 0x282356ed550>,
#  <matplotlib.lines.Line2D at 0x282356ed9b0>]

# %%
#importing libraries
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
#scaling data
x_train_scaled = scaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train_scaled)
x_valid_scaled = scaler.fit_transform(x_valid)
x_valid = pd.DataFrame(x_valid_scaled)

#using gridsearch to find the best parameter
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}
knn = neighbors.KNeighborsRegressor()
model = GridSearchCV(knn, params, cv=5)

#fit the model and make predictions
model.fit(x_train,y_train)
preds = model.predict(x_valid)
# Out:
# C:\Users\vikra\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype bool, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Users\vikra\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype bool, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Users\vikra\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
#rmse
rms=np.sqrt(np.mean(np.power((np.array(y_valid)-np.array(preds)),2)))
rms
# Out:
# 115.17086550026721

# %%
#plot
valid['Predictions'] = 0
valid['Predictions'] = preds
plt.plot(valid[['Close', 'Predictions']])
plt.plot(train['Close'])
# Out:
# C:\Users\vikra\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\vikra\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
